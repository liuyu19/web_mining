# %% [markdown]
# # 检索页及内容页
#
# *  本周主要内容：批量抓取页面基础及技巧
# *  上周主要内容：HTML解析（parse HTML）及准备URL生成连续技
# *  20春_Web数据挖掘_week07
# *  电子讲义设计者：廖汉腾, 许智超
# <br/>
# <br/>
#
# -----
# ## 复习
#
# 复习：上周内容，实践
#
# * 猎聘PC版 liepin.com 取工作URL参数的牛肉
# * 生成一连串新URL以进一步爬取数据
#
# -----
# ## 本周内容及学习目标
#
# 本周内容聚焦在
#
# <mark> 如何有系统的把更多页数据(相同结构)作系统性爬取 </mark>

# %%
# %%html
# <style>
# /* 本电子讲义使用之CSS */
# div.code_cell {
#     background-color: #e5f1fe;
# }
# div.cell.selected {
#     background-color: #effee2;
#     font-size: 2rem;
#     line-height: 2.4rem;
# }
# div.cell.selected .rendered_html table {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html pre code {
#     background-color: #C4E4ff;
#     padding: 2px 25px;
# }
# .rendered_html pre {
#     background-color: #99c9ff;
# }
# div.code_cell .CodeMirror {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html img, .rendered_html svg {
#     max-width: 60%;
#     height: auto;
#     float: right;
# }
#
# .rendered_html img[src*="#full"], .rendered_html svg[src*="#full"] {
#     max-width: 100%;
#     height: auto;
#     float: none;
# }
#
# .rendered_html img[src*="#thumbnail"], .rendered_html svg[src*="#thumbnail"] {
#     max-width: 15%;
#     height: auto;
# }
#
# /* Gradient transparent - color - transparent */
# hr {
#     border: 0;
#     border-bottom: 1px dashed #ccc;
# }
# .emoticon{
#     font-size: 5rem;
#     line-height: 4.4rem;
#     text-align: center;
#     vertical-align: middle;
# }
# .bg-split_apply_comine {
#     width: 500px;
#     height: 300px;
#     background: url('02_split-apply-comine_500x300.png') -10px -10px;
#     float: right;
# }
# .bg-comine {
#     width: 175px;
#     height: 150px;
#     background: url('02_split-apply-comine_500x300.png') -280px -80px;
#     float: right;
# }
# .bg-apply {
#     width: 155px;
#     height: 225px;
#     background: url('02_split-apply-comine_500x300.png') -160px -30px;
#     float: right;
# }
# .bg-split {
#     width: 205px;
#     height: 225px;
#     background: url('02_split-apply-comine_500x300.png') -10px -30px;
#     float: right;
# }
# .break {
#                    page-break-after: right;
#                    width:700px;
#                    clear:both;
# }
# </style>
# Out:
# <style>
# /* 本电子讲义使用之CSS */
# div.code_cell {
#     background-color: #e5f1fe;
# }
# div.cell.selected {
#     background-color: #effee2;
#     font-size: 2rem;
#     line-height: 2.4rem;
# }
# div.cell.selected .rendered_html table {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html pre code {
#     background-color: #C4E4ff;
#     padding: 2px 25px;
# }
# .rendered_html pre {
#     background-color: #99c9ff;
# }
# div.code_cell .CodeMirror {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html img, .rendered_html svg {
#     max-width: 60%;
#     height: auto;
#     float: right;
# }
#
# .rendered_html img[src*="#full"], .rendered_html svg[src*="#full"] {
#     max-width: 100%;
#     height: auto;
#     float: none;
# }
#
# .rendered_html img[src*="#thumbnail"], .rendered_html svg[src*="#thumbnail"] {
#     max-width: 15%;
#     height: auto;
# }
#
# /* Gradient transparent - color - transparent */
# hr {
#     border: 0;
#     border-bottom: 1px dashed #ccc;
# }
# .emoticon{
#     font-size: 5rem;
#     line-height: 4.4rem;
#     text-align: center;
#     vertical-align: middle;
# }
# .bg-split_apply_comine {
#     width: 500px;
#     height: 300px;
#     background: url('02_split-apply-comine_500x300.png') -10px -10px;
#     float: right;
# }
# .bg-comine {
#     width: 175px;
#     height: 150px;
#     background: url('02_split-apply-comine_500x300.png') -280px -80px;
#     float: right;
# }
# .bg-apply {
#     width: 155px;
#     height: 225px;
#     background: url('02_split-apply-comine_500x300.png') -160px -30px;
#     float: right;
# }
# .bg-split {
#     width: 205px;
#     height: 225px;
#     background: url('02_split-apply-comine_500x300.png') -10px -30px;
#     float: right;
# }
# .break {
#                    page-break-after: right;
#                    width:700px;
#                    clear:both;
# }
# </style>

# %%
# 基本模块
import pandas as pd
from requests_html import HTMLSession

# %% [markdown]
# ## 0. 上周整合代码

# %%
# 上周C-1B-5 建构 参数模板  
参数_compTag_用户体验 = {'中国500强': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['155'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}, '2018互联网300强': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['182'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}, '制造业500强': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['186'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}, 'AI创新成长50强 ': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['189'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}, '独角兽': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['130'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}, '上市公司': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['156'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}}

# 上周C-1   多个页面准备测试1 中国500强
url = "https://www.liepin.com/zhaopin/"
session = HTMLSession()
payload = 参数_compTag_用户体验['中国500强']
r = session.get( url, params = payload)

# r.url

# 上周C-2  简化 A-1   单一页面爬+解析
session = HTMLSession()

def requests_liepin( url, params):
    r = session.get( url , params = payload)

    # 先取特定元素, 精准打击其子后辈
    主要元素 = r.html.xpath( '//ul[@class="sojob-list"]/li')

    # 作为xpath字典，键为我要抓的牛肉名称，值为xpath
    dict_xpaths={ 
        'text': {
            'edu':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]',
            '经验':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]/following-sibling::span',
            '薪水':    '//div[contains(@class,"job-info")]/p/span[@class="text-warning"]', 
            '时间':    '//div[contains(@class,"job-info")]/p/time/@title', 
            '职称':    '//div[contains(@class,"job-info")]/h3/a', 
            '公司地点': '//div[contains(@class,"job-info")]/p/a',
            '公司名称': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
        },
        'text_content': {
        },
        'href': {
            '链结':    '//div[contains(@class,"job-info")]/h3/a', 
            '公司URL': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
        }
    }

    def get_e_text_content(_xpath_):
        # 高级列表推导
        暂存结果 = [e.xpath(_xpath_)[0].lxml.text_content() for e in 主要元素]
        return(暂存结果)

    def get_e_text(_xpath_):
        # 高级列表推导
        暂存结果 = ["".join([x.strip() if type(x) is str else x.text.strip() for x in e.xpath(_xpath_)]) for e in 主要元素]
        return(暂存结果)

    def get_e_href(_xpath_):
        # 高级列表推导
        暂存结果 = [list(e.xpath(_xpath_, first=True).absolute_links)[0] \
                   if len(e.xpath(_xpath_, first=True).absolute_links) >= 1  \
                   else "" for e in 主要元素]
        return(暂存结果)

    # 只对主要元素下进行.xpath取值
    数据字典 = dict()

    数据字典 = {k:get_e_text_content(v) for k,v in dict_xpaths['text_content'].items()}
    数据字典.update({k:get_e_text(v) for k,v in dict_xpaths['text'].items()})
    数据字典.update({k:get_e_href(v) for k,v in dict_xpaths['href'].items()})

    数据 = pd.DataFrame(数据字典)
    #数据.to_excel("20春_Web数据挖掘_week03_liepin.xlsx", sheet_name="搜查结果")
    return (数据)


# 上周C-3   多个页面
url = "https://www.liepin.com/zhaopin/"

list_df = list()
for k,v in 参数_compTag_用户体验.items():
    payload = v
    df = requests_liepin( url, params = payload)
    df = df.assign (热门公司类型 = k)    
    list_df.append(df)

df_all = pd.concat(list_df)
df_all

# 上周C-4   输出
df_all.to_excel("20春_Web数据挖掘_week03_liepin_各热门公司类型.xlsx", sheet_name="搜查结果")

# 上周C-5 Pandas  基本能力

print (df_all.nunique())
df_all[['edu']].drop_duplicates()

df_all.groupby(['公司名称','edu']).agg({"职称":"count"}).sort_values(by='职称', ascending=False)
# Out:
# edu         6
# 经验          5
# 薪水         76
# 时间         20
# 职称        184
# 公司地点       66
# 公司名称       60
# 链结        193
# 公司URL      61
# 热门公司类型      6
# dtype: int64
#               职称
# 公司名称   edu
# 新洋丰    大专及以上  17
# 滴滴     本科及以上  15
# 阿里巴巴   本科及以上  12
# 洋码头    本科及以上  10
# 新洋丰    本科及以上   9
# ...           ..
# 旷视科技   大专及以上   1
# 明略科技集团 本科及以上   1
# 朗生医药宁波 本科及以上   1
# 浔兴拉链   统招本科    1
# 方太     本科及以上   1
#
# [91 rows x 1 columns]

# %% [markdown]
# -----
#
# ## 本周实践目标
# <mark> 如何有系统的把更多页数据(相同结构)作系统性爬取 </mark>[猎聘PC版](https://www.liepin.com/zhaopin/)
# * 翻页：参数字典的拆解
#   * xpath解析翻页a/@href
#   * 建构参数模板
#   * 建构参数字典
# * 翻页：系统性迭代
#   * robots.txt
#   * 频率及时间
# * 翻页：数据备份与整合
#   * 储存备份
#   * 数据整合

# %% [markdown]
# # 翻页：参数字典的拆解
# ## xpath解析翻页a/@href

# %%
# A-0   单一页面
url = "https://www.liepin.com/zhaopin/?keyword=PRD"
session = HTMLSession()
r = session.get( url )

# %%
# A-1  xpath 解析翻页a/@href
xpath_翻页a = '//div[@class="pagerbar"]/a' # 有disabled, current等href是javascript
xpath_翻页a = '//div[@class="pagerbar"]/a[starts-with(@href,"/zhaopin")]'
print (r.html.xpath(xpath_翻页a)) # 物件

href_列表 = [x.xpath('//@href')[0] for x in r.html.xpath(xpath_翻页a)]
#print (href_列表)

文字_列表 = [x.text for x in r.html.xpath(xpath_翻页a)]
#print (文字_列表)

href_字典 = {x.text:x.xpath('//@href')[0]  for x in r.html.xpath(xpath_翻页a)}
print (href_字典)
# Out:
# [<Element 'a' href='/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=1'>, <Element 'a' href='/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=2'>, <Element 'a' href='/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=3'>, <Element 'a' href='/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=4'>, <Element 'a' href='/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=1'>, <Element 'a' class=('last',) href='/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=9' title='末页'>]
# {'2': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=1', '3': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=2', '4': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=3', '5': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=4', '下一页': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=1', '': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=9'}

# %% [markdown]
# ### 观察：
# 此网页是否给出开始丶步进丶及结束的信息，以方便我们完成迭代设置
#
# * 老问题 URL太长，用上周的URL+query参数解析与pandas数据框找到异同之处
# * 老问题 怎麽系统化出URL？用上周的URL+query参数解析与pandas数据框找到异同之处的时候，顺便构建参数字典，至少让以下参数可调
#   * 搜索关键词：上周keyword
#   * 页码在哪？
# * 实践挑战：如何把上周代码模块化为我们所用？
#
# -----
#
# ## 建构参数模板
#
# ```python
#
# # 上周B-1 使用 urllib.parse 解析
# from urllib.parse import urlparse, parse_qs
#
#
# # 上周B-2 使用 pd.DataFrame进行 unuinque()相异值计量比对
# import pandas as pd
# df = pd.DataFrame([ urlparse(x) for x in 公司数据选择器链结.values()])
# print(df.nunique())
#
# # 上周B-3 针对query 再解析之
# #df_qs = pd.DataFrame([ parse_qs(x) for x in df['query'] ])
# df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])
# print(df.nunique())
#
# # 上周B-4 建构 参数模板 及 字典_compTag
# def parse_url_qs_for_compTag (url):
#     six_parts = urlparse(url)
#     out = parse_qs(six_parts.query)
#     return (out)
#
# # parse_url_qs_for_compTag(list(公司数据选择器链结.values())[0])['compTag']
# 参数模板 = parse_url_qs_for_compTag(list(公司数据选择器链结.values())[0])
# print(参数模板)
# # [ parse_url_qs_for_compTag(x)['compTag'] for x in 公司数据选择器链结.values()]
# [ parse_url_qs_for_compTag(x)['compTag'][0] for x in 公司数据选择器链结.values()]
#
# 字典_compTag = { k:parse_url_qs_for_compTag(v)['compTag'][0] for k,v in 公司数据选择器链结.items()}
# print (字典_compTag)
#
# # B-5 建构 参数模板
# def 参数模板生成(compTag , keyword ):
#     参数 = 参数模板.copy()
#     参数['compTag'] = compTag
#     参数['keyword'] = keyword
#     return (参数)
#
# 参数_compTag_用户体验 = { k:参数模板生成(compTag = [v], keyword = ['用户体验']) for k,v in 字典_compTag.items()}
# print(参数_compTag_用户体验)
#
# ```

# %%
# A-2 建构参数模板：找到关键参数及参数结构

# 需要模组库
from urllib.parse import urlparse, parse_qs
import pandas as pd
from IPython.display import display, HTML

# 总体目标：输入 href_列表, 建构出参数字典

# urlparse 解析后丢入数据框
df = pd.DataFrame([ urlparse(x) for x in href_列表])
df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])

display(df)
print(df.nunique())
display(df_qs)
print(df_qs.nunique())

df_qs.curPage
df_qs = df_qs.assign (curPage_int=df_qs.curPage.astype(int)) # 变成整数
# Out:
#   scheme netloc       path params  \
# 0                /zhaopin/
# 1                /zhaopin/
# 2                /zhaopin/
# 3                /zhaopin/
# 4                /zhaopin/
# 5                /zhaopin/
#
#                                                query fragment
# 0  init=-1&headckid=260c913c0571747b&fromSearchBt...
# 1  init=-1&headckid=260c913c0571747b&fromSearchBt...
# 2  init=-1&headckid=260c913c0571747b&fromSearchBt...
# 3  init=-1&headckid=260c913c0571747b&fromSearchBt...
# 4  init=-1&headckid=260c913c0571747b&fromSearchBt...
# 5  init=-1&headckid=260c913c0571747b&fromSearchBt...
# scheme      1
# netloc      1
# path        1
# params      1
# query       5
# fragment    1
# dtype: int64
#   init          headckid fromSearchBtn keyword                         ckid  \
# 0   -1  260c913c0571747b             2     PRD  260c913c0571747b°radeFlag=0
# 1   -1  260c913c0571747b             2     PRD  260c913c0571747b°radeFlag=0
# 2   -1  260c913c0571747b             2     PRD  260c913c0571747b°radeFlag=0
# 3   -1  260c913c0571747b             2     PRD  260c913c0571747b°radeFlag=0
# 4   -1  260c913c0571747b             2     PRD  260c913c0571747b°radeFlag=0
# 5   -1  260c913c0571747b             2     PRD  260c913c0571747b°radeFlag=0
#
#                                            siTag         d_sfrom  \
# 0  1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw  search_unknown
# 1  1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw  search_unknown
# 2  1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw  search_unknown
# 3  1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw  search_unknown
# 4  1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw  search_unknown
# 5  1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw  search_unknown
#
#                              d_ckId d_curPage d_pageSize  \
# 0  917a54aacc3a11183fcafabd322be908         0         40
# 1  917a54aacc3a11183fcafabd322be908         0         40
# 2  917a54aacc3a11183fcafabd322be908         0         40
# 3  917a54aacc3a11183fcafabd322be908         0         40
# 4  917a54aacc3a11183fcafabd322be908         0         40
# 5  917a54aacc3a11183fcafabd322be908         0         40
#
#                            d_headId curPage
# 0  917a54aacc3a11183fcafabd322be908       1
# 1  917a54aacc3a11183fcafabd322be908       2
# 2  917a54aacc3a11183fcafabd322be908       3
# 3  917a54aacc3a11183fcafabd322be908       4
# 4  917a54aacc3a11183fcafabd322be908       1
# 5  917a54aacc3a11183fcafabd322be908       9
# init             1
# headckid         1
# fromSearchBtn    1
# keyword          1
# ckid             1
# siTag            1
# d_sfrom          1
# d_ckId           1
# d_curPage        1
# d_pageSize       1
# d_headId         1
# curPage          5
# dtype: int64

# %% [markdown]
# ### 观察：
# * query
# * curPage 5次, 最大值9, 本页不算?
#
# -----
#
# ## 建构参数模板：curPage

# %%
# A-2 建构参数模板：找到关键参数及参数结构

def parse_url_qs_for_curPage (url):
    six_parts = urlparse(url) 
    out = parse_qs(six_parts.query)
    return (out)

# 取一例做模板
参数模板 = parse_url_qs_for_curPage(href_列表[0])
print (参数模板)

print (href_字典)
# Out:
# {'init': ['-1'], 'headckid': ['260c913c0571747b'], 'fromSearchBtn': ['2'], 'keyword': ['PRD'], 'ckid': ['260c913c0571747b°radeFlag=0'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['917a54aacc3a11183fcafabd322be908'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['917a54aacc3a11183fcafabd322be908'], 'curPage': ['1']}
# {'2': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=1', '3': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=2', '4': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=3', '5': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=4', '下一页': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=1', '': '/zhaopin/?init=-1&headckid=260c913c0571747b&fromSearchBtn=2&keyword=PRD&ckid=260c913c0571747b°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=917a54aacc3a11183fcafabd322be908&d_curPage=0&d_pageSize=40&d_headId=917a54aacc3a11183fcafabd322be908&curPage=9'}

# %%
# A-3 建构参数模板生成器：keyword curPage
def 参数模板生成(keyword, curPage):
    参数 = 参数模板.copy()
    参数['curPage'] = curPage
    参数['keyword'] = keyword
    return (参数)

参数_keyword_用户体验_curPage = { 
    i:参数模板生成(curPage = [i], \
                  keyword = ['用户体验']) \
    for i,v in href_字典.items()\
    }

# print(参数_keyword_用户体验_curPage) # 只生成本页有的额外翻页URL, 并没有推估到&curPage=9,也没有这页

print (df_qs.curPage_int.min()) # 最小值只有1
print (df_qs.curPage_int.max()) # 最大值只有9

# 应该是 0 (本页)....9(最大值)

参数_keyword_用户体验_curPage = { 
    i:参数模板生成(curPage = [i], \
                  keyword = ['用户体验']) \
    for i in range(0,df_qs.curPage_int.max()+1)\
    }
参数_keyword_用户体验_curPage
# Out:
# 1
# 9
# {0: {'init': ['-1'],
#   'headckid': ['260c913c0571747b'],
#   'fromSearchBtn': ['2'],
#   'keyword': ['用户体验'],
#   'ckid': ['260c913c0571747b°radeFlag=0'],
#   'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['917a54aacc3a11183fcafabd322be908'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['917a54aacc3a11183fcafabd322be908'],
#   'curPage': [0]},
#  1: {'init': ['-1'],
#   'headckid': ['260c913c0571747b'],
#   'fromSearchBtn': ['2'],
#   'keyword': ['用户体验'],
#   'ckid': ['260c913c0571747b°radeFlag=0'],
#   'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['917a54aacc3a11183fcafabd322be908'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['917a54aacc3a11183fcafabd322be908'],
#   'curPage': [1]},
#  2: {'init': ['-1'],
#   'headckid': ['260c913c0571747b'],
#   'fromSearchBtn': ['2'],
#   'keyword': ['用户体验'],
#   'ckid': ['260c913c0571747b°radeFlag=0'],
#   'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['917a54aacc3a11183fcafabd322be908'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['917a54aacc3a11183fcafabd322be908'],
#   'curPage': [2]},
#  3: {'init': ['-1'],
#   'headckid': ['260c913c0571747b'],
#   'fromSearchBtn': ['2'],
#   'keyword': ['用户体验'],
#   'ckid': ['260c913c0571747b°radeFlag=0'],
#   'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['917a54aacc3a11183fcafabd322be908'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['917a54aacc3a11183fcafabd322be908'],
#   'curPage': [3]},
#  4: {'init': ['-1'],
#   'headckid': ['260c913c0571747b'],
#   'fromSearchBtn': ['2'],
#   'keyword': ['用户体验'],
#   'ckid': ['260c913c0571747b°radeFlag=0'],
#   'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['917a54aacc3a11183fcafabd322be908'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['917a54aacc3a11183fcafabd322be908'],
#   'curPage': [4]},
#  5: {'init': ['-1'],
#   'headckid': ['260c913c0571747b'],
#   'fromSearchBtn': ['2'],
#   'keyword': ['用户体验'],
#   'ckid': ['260c913c0571747b°radeFlag=0'],
#   'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['917a54aacc3a11183fcafabd322be908'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['917a54aacc3a11183fcafabd322be908'],
#   'curPage': [5]},
#  6: {'init': ['-1'],
#   'headckid': ['260c913c0571747b'],
#   'fromSearchBtn': ['2'],
#   'keyword': ['用户体验'],
#   'ckid': ['260c913c0571747b°radeFlag=0'],
#   'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['917a54aacc3a11183fcafabd322be908'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['917a54aacc3a11183fcafabd322be908'],
#   'curPage': [6]},
#  7: {'init': ['-1'],
#   'headckid': ['260c913c0571747b'],
#   'fromSearchBtn': ['2'],
#   'keyword': ['用户体验'],
#   'ckid': ['260c913c0571747b°radeFlag=0'],
#   'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['917a54aacc3a11183fcafabd322be908'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['917a54aacc3a11183fcafabd322be908'],
#   'curPage': [7]},
#  8: {'init': ['-1'],
#   'headckid': ['260c913c0571747b'],
#   'fromSearchBtn': ['2'],
#   'keyword': ['用户体验'],
#   'ckid': ['260c913c0571747b°radeFlag=0'],
#   'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['917a54aacc3a11183fcafabd322be908'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['917a54aacc3a11183fcafabd322be908'],
#   'curPage': [8]},
#  9: {'init': ['-1'],
#   'headckid': ['260c913c0571747b'],
#   'fromSearchBtn': ['2'],
#   'keyword': ['用户体验'],
#   'ckid': ['260c913c0571747b°radeFlag=0'],
#   'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['917a54aacc3a11183fcafabd322be908'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['917a54aacc3a11183fcafabd322be908'],
#   'curPage': [9]}}

# %% [markdown]
# # 翻页：系统性迭代
#
# ## 爬亦有道
# * robots.txt 站长/网站拥有者给搜索引擎的"道"
# * 频率及时间
#   * 不要爬太快
#   * 尽量像"人"一样礼貌
#   * time.sleep
#
# ```python
#
# # 上周C-3   多个页面
# url = "https://www.liepin.com/zhaopin/"
#
# list_df = list()
# for k,v in 参数_compTag_用户体验.items():
#     payload = v
#     df = requests_liepin( url, params = payload)
#     df = df.assign (热门公司类型 = k)
#     list_df.append(df)
#
# df_all = pd.concat(list_df)
# df_all
# ```

# %%
# B-1 上周C-2  简化 上上周A-1   单一页面爬+解析
session = HTMLSession()

def requests_liepin( url, params):
    r = session.get( url , params = payload)

    # 先取特定元素, 精准打击其子后辈
    主要元素 = r.html.xpath( '//ul[@class="sojob-list"]/li')

    # 作为xpath字典，键为我要抓的牛肉名称，值为xpath
    dict_xpaths={ 
        'text': {
            'edu':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]',
            '经验':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]/following-sibling::span',
            '薪水':    '//div[contains(@class,"job-info")]/p/span[@class="text-warning"]', 
            '时间':    '//div[contains(@class,"job-info")]/p/time/@title', 
            '职称':    '//div[contains(@class,"job-info")]/h3/a', 
            '公司地点': '//div[contains(@class,"job-info")]/p/a',
            '公司名称': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
        },
        'text_content': {
        },
        'href': {
            '链结':    '//div[contains(@class,"job-info")]/h3/a', 
            '公司URL': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
        }
    }

    def get_e_text_content(_xpath_):
        # 高级列表推导
        暂存结果 = [e.xpath(_xpath_)[0].lxml.text_content() for e in 主要元素]
        return(暂存结果)

    def get_e_text(_xpath_):
        # 高级列表推导
        暂存结果 = ["".join([x.strip() if type(x) is str else x.text.strip() for x in e.xpath(_xpath_)]) for e in 主要元素]
        return(暂存结果)

    def get_e_href(_xpath_):
        # 高级列表推导
        暂存结果 = [list(e.xpath(_xpath_, first=True).absolute_links)[0] \
                   if len(e.xpath(_xpath_, first=True).absolute_links) >= 1  \
                   else "" for e in 主要元素]
        return(暂存结果)

    # 只对主要元素下进行.xpath取值
    数据字典 = dict()

    数据字典 = {k:get_e_text_content(v) for k,v in dict_xpaths['text_content'].items()}
    数据字典.update({k:get_e_text(v) for k,v in dict_xpaths['text'].items()})
    数据字典.update({k:get_e_href(v) for k,v in dict_xpaths['href'].items()})

    数据 = pd.DataFrame(数据字典)
    #数据.to_excel("20春_Web数据挖掘_week03_liepin.xlsx", sheet_name="搜查结果")
    return (数据)

# %% [markdown]
# ## 爬亦有道- 不要爬太快
# time.sleep

# %%
# %%time
time.sleep(3+4*random())
# Out:
# Wall time: 4.6 s

# %%
# B-2 多个页面，但放慢脚步 time.sleep
# %%time

import time
from random import random

url = "https://www.liepin.com/zhaopin/"

list_df = list()
for k,v in 参数_keyword_用户体验_curPage.items():
    payload = v
    df = requests_liepin( url, params = payload)
    time.sleep(3+4*random())  #放慢脚步 3-7秒, 平均约5秒
    df = df.assign (curPage = k)  # 区分  curPage
    list_df.append(df)

df_all = pd.concat(list_df).reset_index()
df_all.index.name = '序'

# 上周C-4   输出
df_all.to_excel("20春_Web数据挖掘_week04_liepin_翻页.xlsx",\
                sheet_name="用户体验")

# 预估时间: 5秒*10 =50
# 预估数量: 40*10 =400
# Out:
#       edu    经验          薪水           时间            职称    公司地点  \
# 0   本科及以上  7年以上          面议  2020年04月04日      营销副总（项目）      佛山
# 1   本科及以上  7年以上          面议  2020年04月04日      营销副总（项目）   广州-石井
# 2   本科及以上  7年以上          面议  2020年04月04日      营销副总（项目）      深圳
# 3   本科及以上  1年以上  10-12k·13薪  2020年04月04日      c++开发工程师      北京
# 4    统招本科  6年以上  15-25k·16薪  2020年04月04日        干部管理经理      深圳
# ..    ...   ...         ...          ...           ...     ...
# 35  大专及以上  2年以上   6-10k·12薪  2020年04月03日     人力资源专员/招聘  宁波-鄞州区
# 36   统招本科  经验不限   8-15k·14薪  2020年04月03日  卫星电源控制器研发工程师  苏州-虎丘区
# 37  本科及以上  3年以上          面议  2020年04月03日       销售部销售经理      上海
# 38  大专及以上  2年以上    5-8k·12薪  2020年04月03日         ie工程师      中山
# 39  本科及以上  3年以上   7-20k·12薪  2020年04月03日        广告销售经理  上海-长宁区
#
#               公司名称                                           链结  \
# 0   中国电建地产集团华南区域总部  https://www.liepin.com/job/1927229275.shtml
# 1   中国电建地产集团华南区域总部  https://www.liepin.com/job/1927229273.shtml
# 2   中国电建地产集团华南区域总部  https://www.liepin.com/job/1927229271.shtml
# 3     北京赛普泰克技术有限公司  https://www.liepin.com/job/1927229255.shtml
# 4             华星光电  https://www.liepin.com/job/1927228767.shtml
# ..             ...                                          ...
# 35      宁波渠成集团有限公司  https://www.liepin.com/job/1925226785.shtml
# 36    苏州馥昶空间技术有限公司  https://www.liepin.com/job/1925224865.shtml
# 37   上海大丁自动化科技有限公司  https://www.liepin.com/job/1925196603.shtml
# 38   中山市皇鼎五金制品有限公司  https://www.liepin.com/job/1925097067.shtml
# 39    上海魄力广告传媒有限公司  https://www.liepin.com/job/1925095091.shtml
#
#                                        公司URL  curPage
# 0    https://www.liepin.com/company/9624513/        0
# 1    https://www.liepin.com/company/9624513/        0
# 2    https://www.liepin.com/company/9624513/        0
# 3    https://www.liepin.com/company/7884122/        0
# 4     https://www.liepin.com/company/671058/        0
# ..                                       ...      ...
# 35   https://www.liepin.com/company/8096424/        9
# 36   https://www.liepin.com/company/9665557/        9
# 37  https://www.liepin.com/company/10058443/        9
# 38   https://www.liepin.com/company/9190284/        9
# 39   https://www.liepin.com/company/8239390/        9
#
# [400 rows x 10 columns]

# %%
## 多个页面+多个关键词
time.sleep

# %%
# %%time
# B-3 多个页面+多个关键词
import time
from random import random

url = "https://www.liepin.com/zhaopin/"
xpath_翻页a = '//div[@class="pagerbar"]/a[starts-with(@href,"/zhaopin")]'

keywords = ['用户体验','UX']
list_df = list()

## 第一页试探有多长的页面
for key in keywords:
    payload = 参数模板生成(keyword=[key], curPage=['0'])
    df = requests_liepin( url, params = payload)
    href_列表 = [x.xpath('//@href')[0] for x in r.html.xpath(xpath_翻页a)]
    df = pd.DataFrame([ urlparse(x) for x in href_列表])
    df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])
    df_qs = df_qs.assign (curPage_int=df_qs.curPage.astype(int)) # 变成整数
    长度 = df_qs.curPage_int.max()+1
    参数_keyword_X_curPage = { 
        i:参数模板生成(curPage = [i], \
                      keyword = [key]) \
        for i in range(0,长度)\
        }
    #print (参数_keyword_X_curPage)
    print (key,长度)
    
    for k,v in 参数_keyword_X_curPage.items():
        payload = v
        df = requests_liepin( url, params = payload)
        time.sleep(3+4*random())  #放慢脚步 3-7秒, 平均约5秒
        df = df.assign (keyword = key)  # 区分  keyword    
        df = df.assign (curPage = k)  # 区分  curPage    
        list_df.append(df)
        
df_all = pd.concat(list_df).reset_index()
df_all.index.name = '序'

df_all.to_excel("20春_Web数据挖掘_week04_liepin_翻页.xlsx",\
                sheet_name="_".join(keywords))
# 预估时间: 2*5秒*10 =100
# 预估数量: 2*40*10 =800
# Out:
# 用户体验 10
# UX 10
# Wall time: 1min 54s

# %% [markdown]
# -----
#
#
# # 翻页：数据备份与整合
# 多个页面+多个关键词执行时，若怕中断最好把每一页的df内容备份做中继

# %%
# 基本模块
import pandas as pd
from requests_html import HTMLSession
from urllib.parse import urlparse, parse_qs
from IPython.display import display, HTML

# %%
url = "https://www.liepin.com/zhaopin/"
session = HTMLSession()
r = session.get( url )

# %%
r.url
# Out:
# 'https://www.liepin.com/zhaopin/'

# %%
# 先取特定元素, 精准打击其子后辈
主要元素 = r.html.xpath('//div[@data-selector="search-conditions"]')
# 预期是一个元素的列表？
print (主要元素[0].xpath('//dd[@data-param="industries"]'))
# Out:
# [<Element 'dd' class=('short-dd', 'select-industry') data-param='industries'>]

# %%
选
# Out:
# [<Element 'dl' class=('clearfix', 'comp-list-box')>,
#  <Element 'dl' class=('clearfix',)>,
#  <Element 'dl' class=('clearfix',)>,
#  <Element 'dl' class=('clearfix',)>,
#  <Element 'dl' class=('clearfix',)>]

# %%
v.xpath('//a[not(img)]/text()'
# Out:
#   File "<ipython-input-148-7741491eee62>", line 1
#     v.xpath('//a[not(img)]/text()'
#                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
v.xpath('//a[not(img)]/text()') + "2"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-149-612ccbdbe06a> in <module>
# ----> 1 v.xpath('//a[not(img)]/text()') + "2"
#
# AttributeError: 'dict' object has no attribute 'xpath'

# %%
for v in 选 :
    #print ( v.xpath('//dt') , v.xpath('//dt//following-sibling::dd') )
    #print ( v.xpath('//dt[@class="search-title"]/text()') , v.xpath('//dt//following-sibling::dd') )
    #print ( v.xpath('//dt[@class="search-title"]/text()')[0] , v.xpath('//dt//following-sibling::dd')[0] )
    print ( v.xpath('//dt[@class="search-title"]/text()', first=True) , 
            v.xpath('//dt//following-sibling::dd', first=True) )
# Out:
# 公司： <Element 'dd' class=('comp-list',)>
# 行业： <Element 'dd' class=('short-dd', 'select-industry') data-param='industries'>
# 城市： <Element 'dd' data-param='city'>
# 薪资： <Element 'dd' data-param='salary'>
# 更多： <Element 'dd' class=('dropdown', 'dropdown-time')>

# %%
for v in sel_main:
#    print ( v.xpath('//li/span') , v.xpath('//li/div') )
#    print ( v.xpath('//li/span', first=True) , v.xpath('//li/div', first=True) )
#    print ( v.xpath('//li/span', first=True).text , v.xpath('//li/div', first=True) )
#    print ( v.xpath('//li/span', first=True).text , v.xpath('//li/div/a') )
    print ( v.xpath('//li/span', first=True).text , v.xpath('//li/div/a/text()') )
    print ( v.xpath('//li/span', first=True).text , v.xpath('//li/div/a/@href') )
# Out:
# 互联网·游戏·软件 ['互联网/电商', '游戏产业', '计算机软件', 'IT服务']
# 互联网·游戏·软件 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=040&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=420&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=010&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=030&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']
# 电子·通信·硬件 ['电子/芯片/半导体', '通信业', '计算机/网络设备']
# 电子·通信·硬件 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_02&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=050&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_02&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=060&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_02&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=020&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']
# 房地产·建筑·物业 ['房地产/建筑', '规划/设计/装潢', '房地产服务']
# 房地产·建筑·物业 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_03&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=080&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_03&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=100&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_03&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=090&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']
# 金融 ['银行', '保险', '基金/证券/投资', '会计/审计', '信托/担保/拍卖']
# 金融 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_04&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=130&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_04&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=140&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_04&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=150&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_04&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=430&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_04&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=500&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']
# 消费品 ['快消品', '批发零售', '服装纺织', '家具/家电', '办公设备', '奢侈品/收藏品', '珠宝/玩具/工艺品']
# 消费品 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=190&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=240&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=200&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=210&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=220&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=460&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=470&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']
# 汽车·机械·制造 ['汽车/摩托车', '机械/机电/重工', '印刷/包装/造纸', '原材料加工', '仪器/电气/自动化']
# 汽车·机械·制造 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_06&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=350&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_06&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=360&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_06&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=180&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_06&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=370&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_06&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=340&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']
# 制药·医疗 ['制药/生物工程', '医疗/保健/美容', '医疗器械']
# 制药·医疗 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_10&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=270&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_10&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=280&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_10&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=290&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']
# 能源·化工·环保 ['能源/水利', '石油/化工', '采掘/冶炼/矿产', '环保', '新能源']
# 能源·化工·环保 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_11&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=330&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_11&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=310&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_11&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=320&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_11&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=300&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_11&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=490&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']
# 服务·外包·中介 ['专业服务', '中介服务', '外包服务', '检测/认证', '餐饮/酒旅/服务', '文体娱乐', '租赁服务']
# 服务·外包·中介 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=120&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=110&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=440&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=450&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=230&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=260&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=510&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']
# 广告·传媒·教育·文化 ['广告/市场/会展', '影视文化', '教育培训']
# 广告·传媒·教育·文化 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_08&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=070&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_08&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=170&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_08&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=380&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']
# 交通·贸易·物流 ['交通/物流/运输', '贸易/进出口', '航空/航天']
# 交通·贸易·物流 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_09&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=250&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_09&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=160&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_09&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=480&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']
# 政府·农林牧渔 ['政务/公共服务', '农林牧渔', '其他行业']
# 政府·农林牧渔 ['/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041', '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041']

# %%
for v in sel_main:
    industry = v.xpath('//li/span', first=True).text
    for link in v.xpath('//li/div/a'):
        #print (industry, link.text, link.absolute_links)
        #print (industry, link.text, list(link.absolute_links)[0])
        #print (industry, link.text, link.xpath('//@href', first=True))
        print ({"行业":industry, "细分":link.text, "url":link.xpath('//@href', first=True)})
# Out:
# {'行业': '互联网·游戏·软件', '细分': '互联网/电商', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=040&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '互联网·游戏·软件', '细分': '游戏产业', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=420&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '互联网·游戏·软件', '细分': '计算机软件', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=010&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '互联网·游戏·软件', '细分': 'IT服务', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_01&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=030&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '电子·通信·硬件', '细分': '电子/芯片/半导体', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_02&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=050&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '电子·通信·硬件', '细分': '通信业', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_02&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=060&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '电子·通信·硬件', '细分': '计算机/网络设备', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_02&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=020&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '房地产·建筑·物业', '细分': '房地产/建筑', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_03&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=080&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '房地产·建筑·物业', '细分': '规划/设计/装潢', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_03&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=100&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '房地产·建筑·物业', '细分': '房地产服务', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_03&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=090&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '金融', '细分': '银行', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_04&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=130&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '金融', '细分': '保险', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_04&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=140&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '金融', '细分': '基金/证券/投资', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_04&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=150&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '金融', '细分': '会计/审计', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_04&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=430&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '金融', '细分': '信托/担保/拍卖', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_04&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=500&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '消费品', '细分': '快消品', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=190&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '消费品', '细分': '批发零售', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=240&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '消费品', '细分': '服装纺织', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=200&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '消费品', '细分': '家具/家电', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=210&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '消费品', '细分': '办公设备', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=220&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '消费品', '细分': '奢侈品/收藏品', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=460&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '消费品', '细分': '珠宝/玩具/工艺品', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_05&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=470&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '汽车·机械·制造', '细分': '汽车/摩托车', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_06&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=350&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '汽车·机械·制造', '细分': '机械/机电/重工', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_06&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=360&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '汽车·机械·制造', '细分': '印刷/包装/造纸', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_06&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=180&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '汽车·机械·制造', '细分': '原材料加工', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_06&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=370&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '汽车·机械·制造', '细分': '仪器/电气/自动化', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_06&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=340&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '制药·医疗', '细分': '制药/生物工程', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_10&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=270&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '制药·医疗', '细分': '医疗/保健/美容', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_10&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=280&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '制药·医疗', '细分': '医疗器械', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_10&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=290&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '能源·化工·环保', '细分': '能源/水利', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_11&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=330&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '能源·化工·环保', '细分': '石油/化工', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_11&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=310&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '能源·化工·环保', '细分': '采掘/冶炼/矿产', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_11&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=320&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '能源·化工·环保', '细分': '环保', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_11&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=300&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '能源·化工·环保', '细分': '新能源', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_11&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=490&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '服务·外包·中介', '细分': '专业服务', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=120&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '服务·外包·中介', '细分': '中介服务', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=110&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '服务·外包·中介', '细分': '外包服务', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=440&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '服务·外包·中介', '细分': '检测/认证', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=450&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '服务·外包·中介', '细分': '餐饮/酒旅/服务', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=230&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '服务·外包·中介', '细分': '文体娱乐', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=260&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '服务·外包·中介', '细分': '租赁服务', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_07&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=510&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '广告·传媒·教育·文化', '细分': '广告/市场/会展', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_08&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=070&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '广告·传媒·教育·文化', '细分': '影视文化', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_08&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=170&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '广告·传媒·教育·文化', '细分': '教育培训', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_08&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=380&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '交通·贸易·物流', '细分': '交通/物流/运输', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_09&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=250&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '交通·贸易·物流', '细分': '贸易/进出口', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_09&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=160&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '交通·贸易·物流', '细分': '航空/航天', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_09&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=480&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '政府·农林牧渔', '细分': '政务/公共服务', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '政府·农林牧渔', '细分': '农林牧渔', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}
# {'行业': '政府·农林牧渔', '细分': '其他行业', 'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}

# %%
[ {"行业":v.xpath('//li/span', first=True).text, "细分":link.text, "url":link.xpath('//@href', first=True)} \
  for link in v.xpath('//li/div/a') \
  for v in sel_main ]
# Out:
# [{'行业': '互联网·游戏·软件',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '电子·通信·硬件',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '房地产·建筑·物业',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '金融',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '消费品',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '汽车·机械·制造',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '制药·医疗',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '能源·化工·环保',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '服务·外包·中介',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '广告·传媒·教育·文化',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '交通·贸易·物流',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '政府·农林牧渔',
#   '细分': '政务/公共服务',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=390&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '互联网·游戏·软件',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '电子·通信·硬件',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '房地产·建筑·物业',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '金融',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '消费品',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '汽车·机械·制造',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '制药·医疗',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '能源·化工·环保',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '服务·外包·中介',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '广告·传媒·教育·文化',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '交通·贸易·物流',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '政府·农林牧渔',
#   '细分': '农林牧渔',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=410&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '互联网·游戏·软件',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '电子·通信·硬件',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '房地产·建筑·物业',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '金融',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '消费品',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '汽车·机械·制造',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '制药·医疗',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '能源·化工·环保',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '服务·外包·中介',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '广告·传媒·教育·文化',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '交通·贸易·物流',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'},
#  {'行业': '政府·农林牧渔',
#   '细分': '其他行业',
#   'url': '/zhaopin/?subIndustry=&init=-1&industryType=industry_12&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&industries=400&ckid=3de4913c02fe4c5b&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041'}]

# %%
pd.DataFrame(\
[ {"行业":v.xpath('//li/span', first=True).text, "细分":link.text, "url":link.xpath('//@href', first=True)} \
  for link in v.xpath('//li/div/a') \
  for v in sel_main ]   )
# Out:
#              行业       细分                                                url
# 0     互联网·游戏·软件  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 1      电子·通信·硬件  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 2     房地产·建筑·物业  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 3            金融  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 4           消费品  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 5      汽车·机械·制造  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 6         制药·医疗  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 7      能源·化工·环保  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 8      服务·外包·中介  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 9   广告·传媒·教育·文化  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 10     交通·贸易·物流  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 11      政府·农林牧渔  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 12    互联网·游戏·软件     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 13     电子·通信·硬件     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 14    房地产·建筑·物业     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 15           金融     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 16          消费品     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 17     汽车·机械·制造     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 18        制药·医疗     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 19     能源·化工·环保     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 20     服务·外包·中介     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 21  广告·传媒·教育·文化     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 22     交通·贸易·物流     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 23      政府·农林牧渔     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 24    互联网·游戏·软件     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 25     电子·通信·硬件     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 26    房地产·建筑·物业     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 27           金融     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 28          消费品     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 29     汽车·机械·制造     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 30        制药·医疗     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 31     能源·化工·环保     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 32     服务·外包·中介     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 33  广告·传媒·教育·文化     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 34     交通·贸易·物流     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 35      政府·农林牧渔     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...

# %%
for v in sel_C:
    print ( v.text , v.xpath('//@href', first=True) )
# Out:
# 全国 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 北京 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=010&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 上海 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=020&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 广州 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=050020&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 深圳 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=050090&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 天津 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=030&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 苏州 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=060080&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 重庆 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=040&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 南京 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=060020&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 杭州 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=070020&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 大连 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=210040&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 成都 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=280020&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 武汉 /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headckid=3de4913c02fe4c5b&flushckid=1&fromSearchBtn=2&dqs=170020&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=674914e755741dc88ea1b29bf8143041&d_curPage=0&d_pageSize=40&d_headId=674914e755741dc88ea1b29bf8143041
# 其他 javascript:;

# %%
选 = r.html.xpath('//div[@data-selector="search-conditions"]/dl')
选d = { vs.xpath('//dt[@class="search-title"]/text()', first=True) \
        :vs.xpath('//dt//following-sibling::dd', first=True) \
        for vs in 选}
display(选d)

for k, vs in 选d.items():
    print(k)
    if '行业' in k:
        sel_main = vs.xpath('//ul/li')
        df = pd.DataFrame(  [ {"行业": v.xpath('//li/span', first=True).text, \
                               "细分":link.text, \
                               "url":link.xpath('//@href', first=True)} \
                              for link in v.xpath('//li/div/a') \
                              for v in sel_main ]   )   
        display(df)
    else:
        sel_C = vs.xpath('//a[not(img)]')
        变量名 = k.replace("：","")  
        df = pd.DataFrame(  [ {变量名:v.text, "url": v.xpath('//@href', first=True)} \
                              for v in sel_C ]   )   
        display(df)
# Out:
# {'公司：': <Element 'dd' class=('comp-list',)>,
#  '行业：': <Element 'dd' class=('short-dd', 'select-industry') data-param='industries'>,
#  '城市：': <Element 'dd' data-param='city'>,
#  '薪资：': <Element 'dd' data-param='salary'>,
#  '更多：': <Element 'dd' class=('dropdown', 'dropdown-time')>}
# 公司：
#             公司                                                url
# 0          +多选                                       javascript:;
# 1           更多                                       javascript:;
# 2       中国500强  /zhaopin/?init=-1&compTag=155&ckid=3de4913c02f...
# 3  2018互联网300强  /zhaopin/?init=-1&compTag=182&ckid=3de4913c02f...
# 4      制造业500强  /zhaopin/?init=-1&compTag=186&ckid=3de4913c02f...
# 5    AI创新成长50强  /zhaopin/?init=-1&compTag=189&ckid=3de4913c02f...
# 6          独角兽  /zhaopin/?init=-1&compTag=130&ckid=3de4913c02f...
# 7         上市公司  /zhaopin/?init=-1&compTag=156&ckid=3de4913c02f...
# 行业：
#              行业       细分                                                url
# 0     互联网·游戏·软件  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 1      电子·通信·硬件  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 2     房地产·建筑·物业  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 3            金融  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 4           消费品  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 5      汽车·机械·制造  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 6         制药·医疗  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 7      能源·化工·环保  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 8      服务·外包·中介  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 9   广告·传媒·教育·文化  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 10     交通·贸易·物流  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 11      政府·农林牧渔  政务/公共服务  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 12    互联网·游戏·软件     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 13     电子·通信·硬件     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 14    房地产·建筑·物业     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 15           金融     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 16          消费品     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 17     汽车·机械·制造     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 18        制药·医疗     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 19     能源·化工·环保     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 20     服务·外包·中介     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 21  广告·传媒·教育·文化     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 22     交通·贸易·物流     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 23      政府·农林牧渔     农林牧渔  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 24    互联网·游戏·软件     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 25     电子·通信·硬件     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 26    房地产·建筑·物业     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 27           金融     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 28          消费品     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 29     汽车·机械·制造     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 30        制药·医疗     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 31     能源·化工·环保     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 32     服务·外包·中介     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 33  广告·传媒·教育·文化     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 34     交通·贸易·物流     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 35      政府·农林牧渔     其他行业  /zhaopin/?subIndustry=&init=-1&industryType=in...
# 城市：
#     城市                                                url
# 0   全国  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 1   北京  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 2   上海  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 3   广州  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 4   深圳  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 5   天津  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 6   苏州  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 7   重庆  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 8   南京  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 9   杭州  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 10  大连  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 11  成都  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 12  武汉  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 13  其他                                       javascript:;
# 薪资：
#         薪资                                                url
# 0   10-15万  /zhaopin/?init=-1&salary=10$15&ckid=3de4913c02...
# 1   15-20万  /zhaopin/?init=-1&salary=15$20&ckid=3de4913c02...
# 2   20-30万  /zhaopin/?init=-1&salary=20$30&ckid=3de4913c02...
# 3   30-50万  /zhaopin/?init=-1&salary=30$50&ckid=3de4913c02...
# 4  50-100万  /zhaopin/?init=-1&salary=50$100&ckid=3de4913c0...
# 5   100万以上  /zhaopin/?init=-1&salary=100$999&ckid=3de4913c...
# 6      自定义                                       javascript:;
# 7       确定                                       javascript:;
# 更多：
#       更多                                                url
# 0     不限  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 1   一天以内  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 2   三天以内  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 3   一周以内  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...
# 4  一个月以内  /zhaopin/?init=-1&ckid=3de4913c02fe4c5b&headck...

# %%
翻页 = r.html.xpath('//div[@class="pagerbar"]/a')
翻页d = [ { "页": p.text, "href" :p.xpath('//@href', first=True)} for p in 翻页 ]
pd.DataFrame(翻页d)
# Out:
#      页                                               href
# 0                                            javascript:;
# 1  上一页                                       javascript:;
# 2    1                                       javascript:;
# 3    2  /zhaopin/?init=-1&headckid=3de4913c02fe4c5b&fr...
# 4    3  /zhaopin/?init=-1&headckid=3de4913c02fe4c5b&fr...
# 5    4  /zhaopin/?init=-1&headckid=3de4913c02fe4c5b&fr...
# 6    5  /zhaopin/?init=-1&headckid=3de4913c02fe4c5b&fr...
# 7  下一页  /zhaopin/?init=-1&headckid=3de4913c02fe4c5b&fr...
# 8       /zhaopin/?init=-1&headckid=3de4913c02fe4c5b&fr...

# %%
[ v.xpath('//dt[@class="search-title"]/text()')[0]  for v in 选 ]
# Out:
# ['公司：', '行业：', '城市：', '薪资：', '更多：']

# %%
选 = r.html.xpath('//div[@data-selector="search-conditions"]/dl')
选d = { v.xpath('//dt[@class="search-title"]/text()')\
        :v.xpath('//following-sibling::dd[@data-param="industries"]')  \
        for v in 选}
display(选d)

#选d['行业：'].xpath('//following-sibling::dd[@data-param="industries"]') \

#               .xpath('//text()')
#               .xpath('//following-sibling::dd[@data-param="industries"]')[0] \
#               .xpath('//li/div[@class="sub-industry"]/a/text()')  # label
#               .xpath('//li/div[@class="sub-industry"]/a/@href')  # label
#               .xpath('//li/span/text()')  # label
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-47511453295e> in <module>
#       2 选d = { v.xpath('//dt[@class="search-title"]/text()')\
#       3         :v.xpath('//following-sibling::dd[@data-param="industries"]')  \
# ----> 4         for v in 选}
#       5 display(选d)
#       6
#
# <ipython-input-83-47511453295e> in <dictcomp>(.0)
#       2 选d = { v.xpath('//dt[@class="search-title"]/text()')\
#       3         :v.xpath('//following-sibling::dd[@data-param="industries"]')  \
# ----> 4         for v in 选}
#       5 display(选d)
#       6
#
# TypeError: unhashable type: 'list'

# %%
选 = r.html.xpath('//div[@data-selector="search-conditions"]')[0] \
           .xpath('//dt[@class="search-title"]') \
#               .xpath('//text()')
#               .xpath('//following-sibling::dd[@data-param="industries"]')[0] \
#               .xpath('//li/div[@class="sub-industry"]/a/text()')  # label
#               .xpath('//li/div[@class="sub-industry"]/a/@href')  # label
#               .xpath('//li/span/text()')  # label
选

#公司数据选择器链结 = { x.xpath("a/text()")[0]:x.xpath("a/@href")[0] for x in 公司数据选择器链结}
#公司数据选择器链结
# Out:
# [<Element 'dt' class=('search-title',)>,
#  <Element 'dt' class=('search-title',)>,
#  <Element 'dt' class=('search-title',)>,
#  <Element 'dt' class=('search-title',)>,
#  <Element 'dt' class=('search-title',)>]

# %%
# 上周B-4 建构 参数模板 及 字典_compTag
def parse_url_qs_for_compTag (url):
    six_parts = urlparse(url) 
    out = parse_qs(six_parts.query)
    return (out)

# parse_url_qs_for_compTag(list(公司数据选择器链结.values())[0])['compTag']
参数模板 = parse_url_qs_for_compTag(list(公司数据选择器链结.values())[0])
print(参数模板)
# [ parse_url_qs_for_compTag(x)['compTag'] for x in 公司数据选择器链结.values()]
[ parse_url_qs_for_compTag(x)['compTag'][0] for x in 公司数据选择器链结.values()]

字典_compTag = { k:parse_url_qs_for_compTag(v)['compTag'][0] for k,v in 公司数据选择器链结.items()}
print (字典_compTag)

# B-5 建构 参数模板  
def 参数模板生成(compTag , keyword ):
    参数 = 参数模板.copy()
    参数['compTag'] = compTag
    参数['keyword'] = keyword
    return (参数)

参数_compTag_用户体验 = { k:参数模板生成(compTag = [v], keyword = ['用户体验']) for k,v in 字典_compTag.items()}
print(参数_compTag_用户体验)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-67896126dcfd> in <module>
#       6
#       7 # parse_url_qs_for_compTag(list(公司数据选择器链结.values())[0])['compTag']
# ----> 8 参数模板 = parse_url_qs_for_compTag(list(公司数据选择器链结.values())[0])
#       9 print(参数模板)
#      10 # [ parse_url_qs_for_compTag(x)['compTag'] for x in 公司数据选择器链结.values()]
#
# NameError: name '公司数据选择器链结' is not defined

# %%
# A-2 建构参数模板：找到关键参数及参数结构
df = pd.DataFrame([ urlparse(x) for x in href_列表])
df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])

display(df)
print(df.nunique())
display(df_qs)
print(df_qs.nunique())

df_qs.curPage
df_qs = df_qs.assign (curPage_int=df_qs.curPage.astype(int)) # 变成整数

# %%
# A-1  xpath 解析翻页a/@href
xpath_翻页a = '//div[@class="pagerbar"]/a' # 有disabled, current等href是javascript
xpath_翻页a = '//div[@class="pagerbar"]/a[starts-with(@href,"/zhaopin")]'
print (r.html.xpath(xpath_翻页a)) # 物件

href_列表 = [x.xpath('//@href')[0] for x in r.html.xpath(xpath_翻页a)]
#print (href_列表)

文字_列表 = [x.text for x in r.html.xpath(xpath_翻页a)]
#print (文字_列表)

href_字典 = {x.text:x.xpath('//@href')[0]  for x in r.html.xpath(xpath_翻页a)}
print (href_字典)
# Out:
# [<Element 'a' href='/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=1'>, <Element 'a' href='/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=2'>, <Element 'a' href='/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=3'>, <Element 'a' href='/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=4'>, <Element 'a' href='/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=1'>, <Element 'a' class=('last',) href='/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=9' title='末页'>]
# {'2': '/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=1', '3': '/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=2', '4': '/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=3', '5': '/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=4', '下一页': '/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=1', '': '/zhaopin/?init=-1&headckid=3614d6ddd7b6c834&fromSearchBtn=2&ckid=3614d6ddd7b6c834°radeFlag=0&siTag=1B2M2Y8AsgTpgAmY7PhCfg%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=ae62252a5c5eef9298680c1b3c045755&d_curPage=0&d_pageSize=40&d_headId=ae62252a5c5eef9298680c1b3c045755&curPage=9'}

# %%
# A-2 建构参数模板：找到关键参数及参数结构

def parse_url_qs_for_curPage (url):
    six_parts = urlparse(url) 
    out = parse_qs(six_parts.query)
    return (out)

# 取一例做模板
参数模板 = parse_url_qs_for_curPage(href_列表[0])
print (参数模板)

print (href_字典)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5d43d1475593> in <module>
#       7
#       8 # 取一例做模板
# ----> 9 参数模板 = parse_url_qs_for_curPage(href_列表[0])
#      10 print (参数模板)
#      11
#
# <ipython-input-13-5d43d1475593> in parse_url_qs_for_curPage(url)
#       2
#       3 def parse_url_qs_for_curPage (url):
# ----> 4     six_parts = urlparse(url)
#       5     out = parse_qs(six_parts.query)
#       6     return (out)
#
# NameError: name 'urlparse' is not defined

# %%
# A-3 建构参数模板生成器：keyword curPage
def 参数模板生成(keyword, curPage):
    参数 = 参数模板.copy()
    参数['curPage'] = curPage
    参数['keyword'] = keyword
    return (参数)

参数_keyword_用户体验_curPage = { 
    i:参数模板生成(curPage = [i], \
                  keyword = ['用户体验']) \
    for i,v in href_字典.items()\
    }

# print(参数_keyword_用户体验_curPage) # 只生成本页有的额外翻页URL, 并没有推估到&curPage=9,也没有这页

print (df_qs.curPage_int.min()) # 最小值只有1
print (df_qs.curPage_int.max()) # 最大值只有9

# 应该是 0 (本页)....9(最大值)

参数_keyword_用户体验_curPage = { 
    i:参数模板生成(curPage = [i], \
                  keyword = ['用户体验']) \
    for i in range(0,df_qs.curPage_int.max()+1)\
    }
参数_keyword_用户体验_curPage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8a3a3ca62a35> in <module>
#       9     i:参数模板生成(curPage = [i], \
#      10                   keyword = ['用户体验']) \
# ---> 11     for i,v in href_字典.items()\
#      12     }
#      13
#
# <ipython-input-11-8a3a3ca62a35> in <dictcomp>(.0)
#       9     i:参数模板生成(curPage = [i], \
#      10                   keyword = ['用户体验']) \
# ---> 11     for i,v in href_字典.items()\
#      12     }
#      13
#
# <ipython-input-11-8a3a3ca62a35> in 参数模板生成(keyword, curPage)
#       1 # A-3 建构参数模板生成器：keyword curPage
#       2 def 参数模板生成(keyword, curPage):
# ----> 3     参数 = 参数模板.copy()
#       4     参数['curPage'] = curPage
#       5     参数['keyword'] = keyword
#
# NameError: name '参数模板' is not defined

# %%
# %%time
# C-1 多个页面+多个关键词
import time
from random import random

url = "https://www.liepin.com/zhaopin/"
xpath_翻页a = '//div[@class="pagerbar"]/a[starts-with(@href,"/zhaopin")]'

keywords = ['用户体验','UX','产品需求','PRD']
list_df = list()

## 第一页试探有多长的页面
for key in keywords:
    payload = 参数模板生成(keyword=[key], curPage=['0'])
    df = requests_liepin( url, params = payload)
    href_列表 = [x.xpath('//@href')[0] for x in r.html.xpath(xpath_翻页a)]
    df = pd.DataFrame([ urlparse(x) for x in href_列表])
    df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])
    df_qs = df_qs.assign (curPage_int=df_qs.curPage.astype(int)) # 变成整数
    长度 = df_qs.curPage_int.max()+1
    参数_keyword_X_curPage = { 
        i:参数模板生成(curPage = [i], \
                      keyword = [key]) \
        for i in range(0,长度)\
        }
    #print (参数_keyword_X_curPage)
    print (key,长度)
    
    for k,v in 参数_keyword_X_curPage.items():
        payload = v
        df = requests_liepin( url, params = payload)
        time.sleep(3+4*random())  #放慢脚步 3-7秒, 平均约5秒
        ## 备份
        df.to_csv("20春_Web数据挖掘_week04_liepin_{key}_{k}.tsv"\
                  .format(key=key, k=k), sep="\t", encoding="utf8")
        
        df = df.assign (keyword = key)  # 区分  keyword    
        df = df.assign (curPage = k)  # 区分  curPage    
        list_df.append(df)
        
df_all = pd.concat(list_df).reset_index()
df_all.index.name = '序'

df_all.to_excel("20春_Web数据挖掘_week04_liepin_翻页_4.xlsx",\
                sheet_name="_".join(keywords))
# 预估时间: 4*5秒*10 =200
# 预估数量: 4*40*10 =1600
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name '参数模板生成' is not defined

# %% [markdown]
# # 本周练习
#
# * 开始试验各类参数的调整
